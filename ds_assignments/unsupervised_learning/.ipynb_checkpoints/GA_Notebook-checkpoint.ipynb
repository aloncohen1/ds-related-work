# %% [markdown]
# # Assignment: Unsupervised Machine Learning \ Genetic Algorithms

# %% [markdown]
# In this assignment you will experience with Genetic Algorithms (GAs), starting from a basic implementation, continuing with dedicated improvements, and later applying it in various unsupervised machine learning scenarios.

# %% [markdown]
# ## Part 1: Time Series of 'Likes' Influenced by Personalization

# %% [markdown]
# Various personalization algorithms are applied in e-commerce and other kinds of websites/apps in order to increase purchases or user engagement.
#
# The following time series were collected over a period of 20 months from a large online retail store. In this study, during the first 10 months (normalized as the period from month -10 to month 0) a contextual personalization algorithm was applied in order to increase user engagement (measured as the accumulated number of 'Likes' on products shared via Facebook). As in the case with many contextual approaches, this algorithm suffered from the 'filter bubble' problem (https://en.wikipedia.org/wiki/Filter_bubble), and therefore reached a plateau quite quickly.
#
# Nonetheless, this step enabled a more advanced collaborative filtering algorithm to analyze the collected data, learn, and increase user engagement once it was applied in the following 10 months. A classic inflection point was detected after the transition to the new algorithm. A domain expert envisioned the inflection dynamics will behave similarly to the formula f(x) = ax^3 + bx^2 + cx + d. The values of a, b, c and d were found to be 4.8, 12.1, 53.2 and 6219, respectively.
#
# << Please note: This function is an analytical solution, used here for simplifying the actual study, where a dynamic model was created with ODEs >>
#
# We are given a sample sparse data of users from 10 different European countries. In this project, we will implement a simple GA in order to fit our data to the above-mentioned function, and discover the parameters for a, b, c and d.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read measured data from an Excel file

# %%
xlsx = pd.ExcelFile('European Measurements.xlsx')
sheet1 = xlsx.parse(3) # Note the other datasets in the file.
variables = ["Month","Avg. Likes"]
data = sheet1.loc[:, variables].values
print(data)
# Out:
# [[-9.70000000e+00  1.93303385e+03]
#  [-9.10000000e+00  3.07678202e+03]
#  [-7.70000000e+00  4.61959427e+03]
#  [-7.30000000e+00  4.87640388e+03]
#  [-7.20000000e+00  5.27621777e+03]
#  [-6.20000000e+00  5.76967851e+03]
#  [-4.70000000e+00  5.26728526e+03]
#  [-4.10000000e+00  6.40777934e+03]
#  [-3.30000000e+00  6.05631612e+03]
#  [-2.70000000e+00  6.10216500e+03]
#  [-2.50000000e+00  5.18359545e+03]
#  [-2.30000000e+00  7.03041233e+03]
#  [-1.90000000e+00  5.69790109e+03]
#  [-1.80000000e+00  5.42920417e+03]
#  [-1.20000000e+00  5.23662184e+03]
#  [-9.00000000e-01  6.28278124e+03]
#  [-1.00000000e-01  6.53285159e+03]
#  [ 2.00000000e-01  5.78284515e+03]
#  [ 3.00000000e-01  6.57445814e+03]
#  [ 4.00000000e-01  5.25761264e+03]
#  [ 1.10000000e+00  5.86568880e+03]
#  [ 1.50000000e+00  6.92127198e+03]
#  [ 1.60000000e+00  6.15982519e+03]
#  [ 2.10000000e+00  6.87265063e+03]
#  [ 2.20000000e+00  5.57408399e+03]
#  [ 2.50000000e+00  5.88485867e+03]
#  [ 5.20000000e+00  6.75130936e+03]
#  [ 5.40000000e+00  7.32399792e+03]
#  [ 5.90000000e+00  7.52506753e+03]
#  [ 7.70000000e+00  9.18581240e+03]
#  [ 8.20000000e+00  1.04493680e+04]
#  [ 8.60000000e+00  1.15189098e+04]
#  [ 8.80000000e+00  1.11537874e+04]
#  [ 8.90000000e+00  1.11901243e+04]
#  [ 9.50000000e+00  1.13409561e+04]]

# %% [markdown]
# ### Simple GA mechanism

# %%
def fitness_function(data, pop):
    fitness = []
    for solution in range(len(pop)):
        error = 0;
        for event in range(len(data)):
            event_time = data[event][0]
            event_measured = data[event][1]
            event_expected = pop[solution][0]*event_time**3 + pop[solution][1]*event_time**2 + pop[solution][2]*event_time + pop[solution][3]
            error +=(event_expected - event_measured)**2
        fitness.append(1/error) # We use 1/error in order to use a maximization mechanism, while we want to minimize the error
    return fitness

def biased_selection(pop, fitness, num_parents):
    sorted_fitness_args = np.argsort(fitness)
    return pop[sorted_fitness_args[-num_parents:],:]
    # parents = np.empty((num_parents, pop.shape[1]))
    # for parent_num in range(num_parents):
    #     max_fitness_idx = np.where(fitness == np.max(fitness))
    #     max_fitness_idx = max_fitness_idx[0][0]
    #     parents[parent_num, :] = pop[max_fitness_idx, :]
    #     fitness[max_fitness_idx] = -99999999999
    # return parents

def recombination(parents, offspring_size):
    offspring = np.empty(offspring_size)
    recombination_point = np.uint8(offspring_size[1]/2)
    for k in range(offspring_size[0]):
        parent1_idx = k%parents.shape[0]
        parent2_idx = (k+1)%parents.shape[0]
        offspring[k, 0:recombination_point] = parents[parent1_idx, 0:recombination_point]
        offspring[k, recombination_point:] = parents[parent2_idx, recombination_point:]
    return offspring

def mutation(offspring_recombination):
    for idx in range(offspring_recombination.shape[0]):
        random_value = np.random.randint(-100, 100, 1)
        random_index = np.random.randint(0,offspring_recombination.shape[1],1)
        offspring_recombination[idx, random_index] = offspring_recombination[idx, random_index] + random_value
    return offspring_recombination

# %% [markdown]
# ### GA application for fitting time series data

# %%
# GA Parameters
formula_degree = 4
number_of_solutions = 500
number_of_parents = 250
population_size = (number_of_solutions,formula_degree) 
number_of_generations = 20
best_outputs = []

# Genesis
new_population = np.random.randint(low=0, high=10000, size=population_size)
print("The population of the first generation: ")
print(new_population)

# Evolution
print ("\nEvolution:")
for generation in range(number_of_generations):

    fitness = fitness_function(data, new_population)
    print("Generation = ", generation, "\tBest fitness = ", round(1/np.max(fitness),5))
    # best_outputs.append(np.max(np.sum(new_population*formula_degree, axis=1)))
    best_outputs.append(round(1/np.max(fitness),5))
    parents = biased_selection(new_population, fitness, number_of_parents)
    offspring_recombination = recombination(parents, offspring_size=(population_size[0]-parents.shape[0], formula_degree))
    offspring_mutation = mutation(offspring_recombination)
    new_population[0:parents.shape[0], :] = parents
    new_population[parents.shape[0]:, :] = offspring_mutation

# Results
print("\nThe population of the last generation: ")
print(new_population)
fitness = fitness_function(data, new_population)
best_match_idx = np.where(fitness == np.max(fitness))
print("Best solution: ", new_population[best_match_idx, :])

# Chart
plt.plot(best_outputs)
plt.xlabel("Generation")
plt.ylabel("Best Fitness Score")
plt.show()
# Out:
# The population of the first generation:
# [[1517 7797 4673 9105]
#  [2033 9313 1572 7473]
#  [7501 1085 1223 5191]
#  ...
#  [5787 6145 3261 9109]
#  [2738 6678 8546 8043]
#  [7277 1325 9236 5305]]
#
# Evolution:
# Generation =  0 	Best fitness =  326483575806.131
# Generation =  1 	Best fitness =  326483575806.131
# Generation =  2 	Best fitness =  260747440784.6363
# Generation =  3 	Best fitness =  252730034530.00568
# Generation =  4 	Best fitness =  215109211102.5915
# Generation =  5 	Best fitness =  165972670596.74902
# Generation =  6 	Best fitness =  122657491519.5449
# Generation =  7 	Best fitness =  93777893615.39478
# Generation =  8 	Best fitness =  87661015652.69765
# Generation =  9 	Best fitness =  75047507370.491
# Generation =  10 	Best fitness =  69538295088.96643
# Generation =  11 	Best fitness =  43857246847.13698
# Generation =  12 	Best fitness =  43857246847.13698
# Generation =  13 	Best fitness =  43857246847.13698
# Generation =  14 	Best fitness =  38930250815.7164
# Generation =  15 	Best fitness =  37548829365.28088
# Generation =  16 	Best fitness =  37548829365.28088
# Generation =  17 	Best fitness =  37467561296.90016
# Generation =  18 	Best fitness =  33396104940.97282
# Generation =  19 	Best fitness =  30555239239.01952
#
# The population of the last generation:
# [[  -1  872   60 7202]
#  [   5  864  136 7210]
#  [  12  850  180 7253]
#  ...
#  [  48  708  197 7299]
#  [ -42  688  307 7339]
#  [  76  689   60 7202]]
# Best solution:  [[[ -20  689  307 7339]]]

# %% [markdown]
# ## Challenge 231
# Implement a new and improved GA, based on the one above, by taking the following actions:
#
# 1. Make the bias_selection function give more chances to solutions with better fitness values, but not necesseraly take the best ones, as currently done.
# 2. Make the recombination function make real random recombination along the chromosome and between chromosomes
# 3. Change the mutation rate and/or scale to better avoid local minima while keeping evolution time short
# 4. Apply a smarter stopping criterion
# 5. Consider different GA parameters in order to reach better results

# %%
# Reformat running of GA algorithm as function to be able to easily compare

def run_ga(number_of_solutions = 500, number_of_parents = 250,
           number_of_generations = 20, mutation_range=(-100,100), mutation_rate=1):
    # GA Parameters
    formula_degree = 4
    population_size = (number_of_solutions, formula_degree)
    best_outputs = []

    # Genesis
    new_population = np.random.randint(low=0, high=10000, size=population_size)

    # Evolution
    for generation in range(number_of_generations):

        fitness = fitness_function(data, new_population)
        best_outputs.append(round(1/np.max(fitness), 5))
        parents = biased_selection(new_population, fitness, number_of_parents)
        offspring_recombination = recombination(parents, offspring_size=(population_size[0]-parents.shape[0], formula_degree))
        offspring_mutation = mutation(offspring_recombination)
        new_population[0:parents.shape[0], :] = parents
        new_population[parents.shape[0]:, :] = offspring_mutation
    
    # Chart
    plt.plot(best_outputs)
    plt.xlabel("Generation")
    plt.ylabel("Best Fitness Score")
    plt.show()
    
    # Results
    fitness = fitness_function(data, new_population)
    return (round(1/np.max(fitness), 5))

# %%
# 1
def biased_selection(pop, fitness, num_parents):
    fitness = np.array(fitness)
    fitness_probs = fitness / fitness.sum()
    chosen_samples = np.random.choice(np.arange(len(fitness)), num_parents, p=fitness_probs)
    return pop[chosen_samples, :]

# %%
run_ga()
# Out:
# 2076850736.79571

# %%
# 2
def recombination(parents, offspring_size):
    offspring = np.empty(offspring_size)
    for k in range(offspring_size[0]):
        parent_indexes = np.random.choice(np.arange(parents.shape[0]), 2, replace=False)
        parent1_idx = parent_indexes[0]
        parent2_idx = parent_indexes[1]
        recombination_point = np.random.randint(1, parents.shape[1]-1)
        offspring[k, 0:recombination_point] = parents[parent1_idx, 0:recombination_point]
        offspring[k, recombination_point:] = parents[parent2_idx, recombination_point:]
    return offspring

# %%
run_ga()
# Out:
# 23035571.29696

# %%
# 3
def mutation(offspring_recombination, mutation_scale, mutation_rate):
    for idx in range(offspring_recombination.shape[0]):
        low_val, high_val = mutation_scale
        random_value = np.random.randint(low_val, high_val, mutation_rate)
        random_index = np.random.choice(np.arange(offspring_recombination.shape[1]), mutation_rate)
        offspring_recombination[idx, random_index] = offspring_recombination[idx, random_index] + random_value
    return offspring_recombination

# %%
# Rewrite run ga to send mutation scale and rate to mutation function

def run_ga(number_of_solutions = 500, number_of_parents = 250,
           number_of_generations = 20, mutation_scale=(-100,100), mutation_rate=1):
    # GA Parameters
    formula_degree = 4
    population_size = (number_of_solutions, formula_degree)
    best_outputs = []

    # Genesis
    new_population = np.random.randint(low=0, high=10000, size=population_size)

    # Evolution
    for generation in range(number_of_generations):

        fitness = fitness_function(data, new_population)
        best_outputs.append(round(1/np.max(fitness), 5))
        parents = biased_selection(new_population, fitness, number_of_parents)
        offspring_recombination = recombination(parents, offspring_size=(population_size[0]-parents.shape[0], formula_degree))
        offspring_mutation = mutation(offspring_recombination, mutation_scale, mutation_rate)
        new_population[0:parents.shape[0], :] = parents
        new_population[parents.shape[0]:, :] = offspring_mutation
        

    # Results
    fitness = fitness_function(data, new_population)
    return (round(1/np.max(fitness), 5))

# %%
rates = [1,2,3,4]
scales = [(-100,100), (-50,50), (-20,20), (-10,10), (-5,5), (-1,1)]
best_fitnesses = []

for r in rates:
    for s in scales:
        best_fitnesses.append(run_ga(mutation_scale=s, mutation_rate=r))

best_fitnesses = np.array(best_fitnesses).reshape(len(rates),len(scales))
best_fitness = best_fitnesses.min()
best_indexes = np.where(best_fitnesses == best_fitness)
print(f'value of {best_fitness} acheived with scale of {scales[best_indexes[0][0]]}'
      f' and a rate of {rates[best_indexes[1][0]]}')
# Out:
# value of 9156805.70823 acheived with scale of (-10, 10) and a rate of 2

# %%
# 4
# Rewrite run ga to stop when the ratio of last best fit / best fit is under 5%

def run_ga(number_of_solutions = 500, number_of_parents = 250,
           number_of_generations = 20, mutation_scale=(-100,100), mutation_rate=1):
    # GA Parameters
    formula_degree = 4
    population_size = (number_of_solutions, formula_degree)
    best_outputs = []

    # Genesis
    new_population = np.random.randint(low=0, high=10000, size=population_size)

    # Evolution
    for generation in range(number_of_generations):

        fitness = fitness_function(data, new_population)
        best_outputs.append(round(1/np.max(fitness), 5))
        
        if generation > 1 and best_outputs[-2]/best_outputs[-1] < 1.05:
            break
            
        parents = biased_selection(new_population, fitness, number_of_parents)
        offspring_recombination = recombination(parents, offspring_size=(population_size[0]-parents.shape[0], formula_degree))
        offspring_mutation = mutation(offspring_recombination, mutation_scale, mutation_rate)
        new_population[0:parents.shape[0], :] = parents
        new_population[parents.shape[0]:, :] = offspring_mutation
        
    # Chart
    plt.plot(best_outputs)
    plt.xlabel("Generation")
    plt.ylabel("Best Fitness Score")
    plt.show()


    # Results
    fitness = fitness_function(data, new_population)
    return (round(1/np.max(fitness), 5))

# %%
#5 
num_solutions = [250, 500, 750]
num_parents = [50, 150, 250]
num_gens = [10, 20, 30]
best_fitnesses = []

for s in num_solutions:
    for p in num_parents:
        for g in num_gens:
            best_fitnesses.append(run_ga(number_of_solutions = s, number_of_parents = p,
           number_of_generations = g, mutation_scale=(-10, 10), mutation_rate=2))

best_fitnesses = np.array(best_fitnesses).reshape(len(num_solutions),len(num_parents), len(num_gens))
best_fitness = best_fitnesses.min()
best_indexes = np.where(best_fitnesses == best_fitness)
# print(best_fitness)
# print(best_indexes)
print(f'value of {best_fitness} acheived with {num_solutions[best_indexes[0][0]]} solutions'
      f', {num_parents[best_indexes[1][0]]} parents and {num_gens[best_indexes[2][0]]} generations')
# Out:
# value of 83386887.2816 acheived with 750 solutions, 50 parents and 20 generations

# %% [markdown]
# ## Part 2: Solving Different Problems With the Same GA

# %% [markdown]
# Below is a reminder of the K-Means algorithm you implemented in Assignment 21X.

# %%
from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import Axes3D

xlsx = pd.ExcelFile('EMR-Blood.xlsx')
sheet1 = xlsx.parse(0)
sheet1.set_index("Key", inplace=True)

variables1 = ["K","WBC","Hgb"]
EMR3d1 = sheet1.loc[:, variables1].values

y_pred_KMeans1 = KMeans(n_clusters=3).fit_predict(EMR3d1)

def make_chart (chart_data, y_pred, labels):
    fig = plt.figure()
    ax = Axes3D(fig)
    ax.set_xlabel(labels[0])
    ax.set_ylabel(labels[1])
    ax.set_zlabel(labels[2])
    ax.scatter(chart_data[:,0], chart_data[:,1], chart_data[:,2], c=y_pred)

make_chart(EMR3d1, y_pred_KMeans1, variables1)

# %% [markdown]
# ### Challenge 232
# Solve the same clustering problem with a GA **without assuming K** (no iteration over differnet Ks), by trying to minimize the intra-cluster distances and maximize the inter-cluster distances.
#
# **hint: You can build the population as the cluster assignment of each point or as cluster centers (consider coordinates boundaries)

# %%
from sklearn.metrics import calinski_harabasz_score 

def fitness_function(data, pop):
    fitness = []
    for i,solution in enumerate(pop):
        # use calinski harabasz score for fitness, based on bcss wcss ratio
        fitness.append(calinski_harabasz_score(data, solution))
    return fitness


def biased_selection(pop, fitness, num_parents):
    fitness = np.array(fitness)
    fitness_probs = fitness / fitness.sum()
    chosen_samples = np.random.choice(np.arange(len(fitness)), num_parents, p=fitness_probs)
    return pop[chosen_samples, :]


def recombination(parents, offspring_size):
    offspring = np.empty(offspring_size)
    for k in range(offspring_size[0]):
        parent_indexes = np.random.choice(np.arange(parents.shape[0]), 2, replace=False)
        parent1_idx = parent_indexes[0]
        parent2_idx = parent_indexes[1]
        recombination_point = np.random.randint(1, parents.shape[1]-1)
        offspring[k, 0:recombination_point] = parents[parent1_idx, 0:recombination_point]
        offspring[k, recombination_point:] = parents[parent2_idx, recombination_point:]
    return offspring


def mutation(offspring_recombination, mutation_scale, mutation_rate, max_value):
    for idx in range(offspring_recombination.shape[0]):
        low_val, high_val = mutation_scale
        random_value = np.random.randint(low_val, high_val, mutation_rate)
        random_index = np.random.choice(np.arange(offspring_recombination.shape[1]), mutation_rate)
        offspring_recombination[idx, random_index] = offspring_recombination[idx, random_index] + random_value
        offspring_recombination[idx, random_index] = offspring_recombination[idx, random_index] % (max_value-1)
    return offspring_recombination


def run_ga(number_of_solutions=1000, number_of_parents=200,
           number_of_generations=1200, mutation_scale=(-1, 1), mutation_rate=2):
    # GA Parameters
    m = EMR3d1.shape[0]
    max_clusters = 9
    population_size = (number_of_solutions, m)
    best_outputs = []

    # Genesis
    new_population = np.random.randint(low=0, high=max_clusters-1, size=population_size)
    print("The population of the first generation: ")
    print(new_population)

    # Evolution
    # Evolution
    print("\nEvolution:")
    for generation in range(number_of_generations):
        fitness = fitness_function(EMR3d1, new_population)
        print("Generation = ", generation, "\tBest fitness = ", round(1 / np.max(fitness), 5))
        # best_outputs.append(np.max(np.sum(new_population*formula_degree, axis=1)))
        best_outputs.append(round(1 / np.max(fitness), 5))
        parents = biased_selection(new_population, fitness, number_of_parents)
        offspring_recombination = recombination(parents,
                                                offspring_size=(population_size[0] - parents.shape[0], m))
        offspring_mutation = mutation(offspring_recombination, mutation_scale, mutation_rate, max_clusters)
        new_population[0:parents.shape[0], :] = parents
        new_population[parents.shape[0]:, :] = offspring_mutation

    # Results
    print("\nThe population of the last generation: ")
    print(new_population)
    fitness = fitness_function(EMR3d1, new_population)
    best_match_idx = np.where(fitness == np.max(fitness))
    best_solution = new_population[best_match_idx, :]
    print("Best solution: ", best_solution)

    # Chart
    plt.plot(best_outputs)
    plt.xlabel("Generation")
    plt.ylabel("Best Fitness Score")
    plt.show()

    return best_solution

# %%
best_solution = run_ga()
# Out:
# The population of the first generation:
# [[0 5 5 ... 6 1 7]
#  [4 5 6 ... 3 4 1]
#  [5 2 1 ... 4 3 6]
#  ...
#  [2 3 7 ... 4 1 0]
#  [4 5 7 ... 3 4 4]
#  [5 6 5 ... 0 0 1]]
#
# Evolution:
# Generation =  0 	Best fitness =  0.34795
# Generation =  1 	Best fitness =  0.3526
# Generation =  2 	Best fitness =  0.32111
# Generation =  3 	Best fitness =  0.25374
# Generation =  4 	Best fitness =  0.20114
# Generation =  5 	Best fitness =  0.24733
# Generation =  6 	Best fitness =  0.20128
# Generation =  7 	Best fitness =  0.19165
# Generation =  8 	Best fitness =  0.17451
# Generation =  9 	Best fitness =  0.17451
# Generation =  10 	Best fitness =  0.17252
# Generation =  11 	Best fitness =  0.17451
# Generation =  12 	Best fitness =  0.17
# Generation =  13 	Best fitness =  0.16105
# Generation =  14 	Best fitness =  0.15059
# Generation =  15 	Best fitness =  0.16521
# Generation =  16 	Best fitness =  0.15656
# Generation =  17 	Best fitness =  0.15744
# Generation =  18 	Best fitness =  0.15626
# Generation =  19 	Best fitness =  0.15298
# Generation =  20 	Best fitness =  0.1366
# Generation =  21 	Best fitness =  0.14219
# Generation =  22 	Best fitness =  0.14375
# Generation =  23 	Best fitness =  0.13741
# Generation =  24 	Best fitness =  0.13423
# Generation =  25 	Best fitness =  0.13433
# Generation =  26 	Best fitness =  0.13252
# Generation =  27 	Best fitness =  0.13091
# Generation =  28 	Best fitness =  0.12458
# Generation =  29 	Best fitness =  0.12414
# Generation =  30 	Best fitness =  0.11568
# Generation =  31 	Best fitness =  0.1128
# Generation =  32 	Best fitness =  0.11555
# Generation =  33 	Best fitness =  0.1154
# Generation =  34 	Best fitness =  0.10912
# Generation =  35 	Best fitness =  0.11427
# Generation =  36 	Best fitness =  0.11541
# Generation =  37 	Best fitness =  0.10883
# Generation =  38 	Best fitness =  0.11133
# Generation =  39 	Best fitness =  0.10229
# Generation =  40 	Best fitness =  0.10477
# Generation =  41 	Best fitness =  0.10766
# Generation =  42 	Best fitness =  0.10582
# Generation =  43 	Best fitness =  0.10541
# Generation =  44 	Best fitness =  0.10385
# Generation =  45 	Best fitness =  0.09507
# Generation =  46 	Best fitness =  0.09507
# Generation =  47 	Best fitness =  0.08099
# Generation =  48 	Best fitness =  0.08099
# Generation =  49 	Best fitness =  0.08099
# Generation =  50 	Best fitness =  0.08099
# Generation =  51 	Best fitness =  0.08099
# Generation =  52 	Best fitness =  0.08637
# Generation =  53 	Best fitness =  0.08637
# Generation =  54 	Best fitness =  0.0854
# Generation =  55 	Best fitness =  0.07873
# Generation =  56 	Best fitness =  0.08527
# Generation =  57 	Best fitness =  0.07991
# Generation =  58 	Best fitness =  0.07852
# Generation =  59 	Best fitness =  0.08133
# Generation =  60 	Best fitness =  0.08554
# Generation =  61 	Best fitness =  0.08256
# Generation =  62 	Best fitness =  0.08261
# Generation =  63 	Best fitness =  0.08141
# Generation =  64 	Best fitness =  0.08286
# Generation =  65 	Best fitness =  0.0829
# Generation =  66 	Best fitness =  0.08077
# Generation =  67 	Best fitness =  0.07772
# Generation =  68 	Best fitness =  0.07333
# Generation =  69 	Best fitness =  0.07175
# Generation =  70 	Best fitness =  0.07175
# Generation =  71 	Best fitness =  0.07658
# Generation =  72 	Best fitness =  0.0718
# Generation =  73 	Best fitness =  0.07399
# Generation =  74 	Best fitness =  0.07463
# Generation =  75 	Best fitness =  0.07716
# Generation =  76 	Best fitness =  0.07207
# Generation =  77 	Best fitness =  0.07535
# Generation =  78 	Best fitness =  0.07453
# Generation =  79 	Best fitness =  0.07221
# Generation =  80 	Best fitness =  0.07075
# Generation =  81 	Best fitness =  0.06799
# Generation =  82 	Best fitness =  0.06234
# Generation =  83 	Best fitness =  0.06121
# Generation =  84 	Best fitness =  0.06847
# Generation =  85 	Best fitness =  0.0609
# Generation =  86 	Best fitness =  0.0609
# Generation =  87 	Best fitness =  0.06398
# Generation =  88 	Best fitness =  0.06594
# Generation =  89 	Best fitness =  0.06708
# Generation =  90 	Best fitness =  0.06364
# Generation =  91 	Best fitness =  0.05888
# Generation =  92 	Best fitness =  0.06948
# Generation =  93 	Best fitness =  0.06163
# Generation =  94 	Best fitness =  0.05942
# Generation =  95 	Best fitness =  0.06123
# Generation =  96 	Best fitness =  0.06266
# Generation =  97 	Best fitness =  0.05709
# Generation =  98 	Best fitness =  0.05654
# Generation =  99 	Best fitness =  0.0543
# Generation =  100 	Best fitness =  0.05875
# Generation =  101 	Best fitness =  0.05476
# Generation =  102 	Best fitness =  0.05509
# Generation =  103 	Best fitness =  0.05396
# Generation =  104 	Best fitness =  0.04976
# Generation =  105 	Best fitness =  0.05286
# Generation =  106 	Best fitness =  0.051
# Generation =  107 	Best fitness =  0.05236
# Generation =  108 	Best fitness =  0.05182
# Generation =  109 	Best fitness =  0.04362
# Generation =  110 	Best fitness =  0.0542
# Generation =  111 	Best fitness =  0.05528
# Generation =  112 	Best fitness =  0.0543
# Generation =  113 	Best fitness =  0.05339
# Generation =  114 	Best fitness =  0.04999
# Generation =  115 	Best fitness =  0.04677
# Generation =  116 	Best fitness =  0.05039
# Generation =  117 	Best fitness =  0.05579
# Generation =  118 	Best fitness =  0.04923
# Generation =  119 	Best fitness =  0.05095
# Generation =  120 	Best fitness =  0.0481
# Generation =  121 	Best fitness =  0.04698
# Generation =  122 	Best fitness =  0.04698
# Generation =  123 	Best fitness =  0.04946
# Generation =  124 	Best fitness =  0.05081
# Generation =  125 	Best fitness =  0.04637
# Generation =  126 	Best fitness =  0.0506
# Generation =  127 	Best fitness =  0.04573
# Generation =  128 	Best fitness =  0.04827
# Generation =  129 	Best fitness =  0.04812
# Generation =  130 	Best fitness =  0.0474
# Generation =  131 	Best fitness =  0.04643
# Generation =  132 	Best fitness =  0.04233
# Generation =  133 	Best fitness =  0.04621
# Generation =  134 	Best fitness =  0.04443
# Generation =  135 	Best fitness =  0.03999
# Generation =  136 	Best fitness =  0.04406
# Generation =  137 	Best fitness =  0.04151
# Generation =  138 	Best fitness =  0.04406
# Generation =  139 	Best fitness =  0.04169
# Generation =  140 	Best fitness =  0.04878
# Generation =  141 	Best fitness =  0.04806
# Generation =  142 	Best fitness =  0.04445
# Generation =  143 	Best fitness =  0.04581
# Generation =  144 	Best fitness =  0.04128
# Generation =  145 	Best fitness =  0.042
# Generation =  146 	Best fitness =  0.04087
# Generation =  147 	Best fitness =  0.04385
# Generation =  148 	Best fitness =  0.04219
# Generation =  149 	Best fitness =  0.03834
# Generation =  150 	Best fitness =  0.0421
# Generation =  151 	Best fitness =  0.03721
# Generation =  152 	Best fitness =  0.04046
# Generation =  153 	Best fitness =  0.04073
# Generation =  154 	Best fitness =  0.04405
# Generation =  155 	Best fitness =  0.04475
# Generation =  156 	Best fitness =  0.03989
# Generation =  157 	Best fitness =  0.03862
# Generation =  158 	Best fitness =  0.03862
# Generation =  159 	Best fitness =  0.04325
# Generation =  160 	Best fitness =  0.03949
# Generation =  161 	Best fitness =  0.04471
# Generation =  162 	Best fitness =  0.04335
# Generation =  163 	Best fitness =  0.04252
# Generation =  164 	Best fitness =  0.04325
# Generation =  165 	Best fitness =  0.04121
# Generation =  166 	Best fitness =  0.03649
# Generation =  167 	Best fitness =  0.03649
# Generation =  168 	Best fitness =  0.03674
# Generation =  169 	Best fitness =  0.03768
# Generation =  170 	Best fitness =  0.03653
# Generation =  171 	Best fitness =  0.03768
# Generation =  172 	Best fitness =  0.03532
# Generation =  173 	Best fitness =  0.03851
# Generation =  174 	Best fitness =  0.03485
# Generation =  175 	Best fitness =  0.03807
# Generation =  176 	Best fitness =  0.03672
# Generation =  177 	Best fitness =  0.0348
# Generation =  178 	Best fitness =  0.03868
# Generation =  179 	Best fitness =  0.03555
# Generation =  180 	Best fitness =  0.03571
# Generation =  181 	Best fitness =  0.03571
# Generation =  182 	Best fitness =  0.03571
# Generation =  183 	Best fitness =  0.03713
# Generation =  184 	Best fitness =  0.03097
# Generation =  185 	Best fitness =  0.03097
# Generation =  186 	Best fitness =  0.03063
# Generation =  187 	Best fitness =  0.03063
# Generation =  188 	Best fitness =  0.03017
# Generation =  189 	Best fitness =  0.03113
# Generation =  190 	Best fitness =  0.02793
# Generation =  191 	Best fitness =  0.02793
# Generation =  192 	Best fitness =  0.03208
# Generation =  193 	Best fitness =  0.03481
# Generation =  194 	Best fitness =  0.0348
# Generation =  195 	Best fitness =  0.03392
# Generation =  196 	Best fitness =  0.03154
# Generation =  197 	Best fitness =  0.03154
# Generation =  198 	Best fitness =  0.03082
# Generation =  199 	Best fitness =  0.03339
# Generation =  200 	Best fitness =  0.0317
# Generation =  201 	Best fitness =  0.02949
# Generation =  202 	Best fitness =  0.02894
# Generation =  203 	Best fitness =  0.03143
# Generation =  204 	Best fitness =  0.03144
# Generation =  205 	Best fitness =  0.03257
# Generation =  206 	Best fitness =  0.03503
# Generation =  207 	Best fitness =  0.02994
# Generation =  208 	Best fitness =  0.03495
# Generation =  209 	Best fitness =  0.03528
# Generation =  210 	Best fitness =  0.03312
# Generation =  211 	Best fitness =  0.03398
# Generation =  212 	Best fitness =  0.03308
# Generation =  213 	Best fitness =  0.03336
# Generation =  214 	Best fitness =  0.03167
# Generation =  215 	Best fitness =  0.03489
# Generation =  216 	Best fitness =  0.032
# Generation =  217 	Best fitness =  0.03125
# Generation =  218 	Best fitness =  0.032
# Generation =  219 	Best fitness =  0.03206
# Generation =  220 	Best fitness =  0.02919
# Generation =  221 	Best fitness =  0.03414
# Generation =  222 	Best fitness =  0.03175
# Generation =  223 	Best fitness =  0.03175
# Generation =  224 	Best fitness =  0.03221
# Generation =  225 	Best fitness =  0.02888
# Generation =  226 	Best fitness =  0.03153
# Generation =  227 	Best fitness =  0.0317
# Generation =  228 	Best fitness =  0.03205
# Generation =  229 	Best fitness =  0.0309
# Generation =  230 	Best fitness =  0.03113
# Generation =  231 	Best fitness =  0.02818
# Generation =  232 	Best fitness =  0.02855
# Generation =  233 	Best fitness =  0.02855
# Generation =  234 	Best fitness =  0.02813
# Generation =  235 	Best fitness =  0.02948
# Generation =  236 	Best fitness =  0.03263
# Generation =  237 	Best fitness =  0.03092
# Generation =  238 	Best fitness =  0.03171
# Generation =  239 	Best fitness =  0.03108
# Generation =  240 	Best fitness =  0.0245
# Generation =  241 	Best fitness =  0.03029
# Generation =  242 	Best fitness =  0.02621
# Generation =  243 	Best fitness =  0.02621
# Generation =  244 	Best fitness =  0.0268
# Generation =  245 	Best fitness =  0.02747
# Generation =  246 	Best fitness =  0.02633
# Generation =  247 	Best fitness =  0.02685
# Generation =  248 	Best fitness =  0.02642
# Generation =  249 	Best fitness =  0.03038
# Generation =  250 	Best fitness =  0.02696
# Generation =  251 	Best fitness =  0.028
# Generation =  252 	Best fitness =  0.02751
# Generation =  253 	Best fitness =  0.02618
# Generation =  254 	Best fitness =  0.02459
# Generation =  255 	Best fitness =  0.02608
# Generation =  256 	Best fitness =  0.02653
# Generation =  257 	Best fitness =  0.02483
# Generation =  258 	Best fitness =  0.02861
# Generation =  259 	Best fitness =  0.02861
# Generation =  260 	Best fitness =  0.02775
# Generation =  261 	Best fitness =  0.02737
# Generation =  262 	Best fitness =  0.02708
# Generation =  263 	Best fitness =  0.02664
# Generation =  264 	Best fitness =  0.02788
# Generation =  265 	Best fitness =  0.02774
# Generation =  266 	Best fitness =  0.02663
# Generation =  267 	Best fitness =  0.02306
# Generation =  268 	Best fitness =  0.02507
# Generation =  269 	Best fitness =  0.02535
# Generation =  270 	Best fitness =  0.02357
# Generation =  271 	Best fitness =  0.02423
# Generation =  272 	Best fitness =  0.02681
# Generation =  273 	Best fitness =  0.02517
# Generation =  274 	Best fitness =  0.0262
# Generation =  275 	Best fitness =  0.02344
# Generation =  276 	Best fitness =  0.02459
# Generation =  277 	Best fitness =  0.02535
# Generation =  278 	Best fitness =  0.02636
# Generation =  279 	Best fitness =  0.02636
# Generation =  280 	Best fitness =  0.02668
# Generation =  281 	Best fitness =  0.02689
# Generation =  282 	Best fitness =  0.0237
# Generation =  283 	Best fitness =  0.02315
# Generation =  284 	Best fitness =  0.02076
# Generation =  285 	Best fitness =  0.02258
# Generation =  286 	Best fitness =  0.02466
# Generation =  287 	Best fitness =  0.02566
# Generation =  288 	Best fitness =  0.02566
# Generation =  289 	Best fitness =  0.02548
# Generation =  290 	Best fitness =  0.02497
# Generation =  291 	Best fitness =  0.02548
# Generation =  292 	Best fitness =  0.02359
# Generation =  293 	Best fitness =  0.02186
# Generation =  294 	Best fitness =  0.02399
# Generation =  295 	Best fitness =  0.02386
# Generation =  296 	Best fitness =  0.02475
# Generation =  297 	Best fitness =  0.02416
# Generation =  298 	Best fitness =  0.02573
# Generation =  299 	Best fitness =  0.02527
# Generation =  300 	Best fitness =  0.02508
# Generation =  301 	Best fitness =  0.02158
# Generation =  302 	Best fitness =  0.02158
# Generation =  303 	Best fitness =  0.02579
# Generation =  304 	Best fitness =  0.02551
# Generation =  305 	Best fitness =  0.02297
# Generation =  306 	Best fitness =  0.02356
# Generation =  307 	Best fitness =  0.02356
# Generation =  308 	Best fitness =  0.02343
# Generation =  309 	Best fitness =  0.02153
# Generation =  310 	Best fitness =  0.02379
# Generation =  311 	Best fitness =  0.02144
# Generation =  312 	Best fitness =  0.02257
# Generation =  313 	Best fitness =  0.02123
# Generation =  314 	Best fitness =  0.02229
# Generation =  315 	Best fitness =  0.02444
# Generation =  316 	Best fitness =  0.02403
# Generation =  317 	Best fitness =  0.0232
# Generation =  318 	Best fitness =  0.02259
# Generation =  319 	Best fitness =  0.02259
# Generation =  320 	Best fitness =  0.01984
# Generation =  321 	Best fitness =  0.02249
# Generation =  322 	Best fitness =  0.02238
# Generation =  323 	Best fitness =  0.01776
# Generation =  324 	Best fitness =  0.0199
# Generation =  325 	Best fitness =  0.02216
# Generation =  326 	Best fitness =  0.02216
# Generation =  327 	Best fitness =  0.02227
# Generation =  328 	Best fitness =  0.02188
# Generation =  329 	Best fitness =  0.01978
# Generation =  330 	Best fitness =  0.02287
# Generation =  331 	Best fitness =  0.02414
# Generation =  332 	Best fitness =  0.02454
# Generation =  333 	Best fitness =  0.02474
# Generation =  334 	Best fitness =  0.02333
# Generation =  335 	Best fitness =  0.02265
# Generation =  336 	Best fitness =  0.02253
# Generation =  337 	Best fitness =  0.02253
# Generation =  338 	Best fitness =  0.02206
# Generation =  339 	Best fitness =  0.02165
# Generation =  340 	Best fitness =  0.02162
# Generation =  341 	Best fitness =  0.02162
# Generation =  342 	Best fitness =  0.02104
# Generation =  343 	Best fitness =  0.02013
# Generation =  344 	Best fitness =  0.0181
# Generation =  345 	Best fitness =  0.01983
# Generation =  346 	Best fitness =  0.01862
# Generation =  347 	Best fitness =  0.01837
# Generation =  348 	Best fitness =  0.0184
# Generation =  349 	Best fitness =  0.02236
# Generation =  350 	Best fitness =  0.02074
# Generation =  351 	Best fitness =  0.01692
# Generation =  352 	Best fitness =  0.01912
# Generation =  353 	Best fitness =  0.01912
# Generation =  354 	Best fitness =  0.01912
# Generation =  355 	Best fitness =  0.02241
# Generation =  356 	Best fitness =  0.02183
# Generation =  357 	Best fitness =  0.02115
# Generation =  358 	Best fitness =  0.02086
# Generation =  359 	Best fitness =  0.02031
# Generation =  360 	Best fitness =  0.02129
# Generation =  361 	Best fitness =  0.02007
# Generation =  362 	Best fitness =  0.01855
# Generation =  363 	Best fitness =  0.01855
# Generation =  364 	Best fitness =  0.01811
# Generation =  365 	Best fitness =  0.01933
# Generation =  366 	Best fitness =  0.01873
# Generation =  367 	Best fitness =  0.01593
# Generation =  368 	Best fitness =  0.01874
# Generation =  369 	Best fitness =  0.02114
# Generation =  370 	Best fitness =  0.0215
# Generation =  371 	Best fitness =  0.02046
# Generation =  372 	Best fitness =  0.01831
# Generation =  373 	Best fitness =  0.01635
# Generation =  374 	Best fitness =  0.01762
# Generation =  375 	Best fitness =  0.01579
# Generation =  376 	Best fitness =  0.01631
# Generation =  377 	Best fitness =  0.01917
# Generation =  378 	Best fitness =  0.01917
# Generation =  379 	Best fitness =  0.01762
# Generation =  380 	Best fitness =  0.01765
# Generation =  381 	Best fitness =  0.01719
# Generation =  382 	Best fitness =  0.01614
# Generation =  383 	Best fitness =  0.01614
# Generation =  384 	Best fitness =  0.01614
# Generation =  385 	Best fitness =  0.01371
# Generation =  386 	Best fitness =  0.01404
# Generation =  387 	Best fitness =  0.01505
# Generation =  388 	Best fitness =  0.01674
# Generation =  389 	Best fitness =  0.01459
# Generation =  390 	Best fitness =  0.01551
# Generation =  391 	Best fitness =  0.01518
# Generation =  392 	Best fitness =  0.01539
# Generation =  393 	Best fitness =  0.01501
# Generation =  394 	Best fitness =  0.01506
# Generation =  395 	Best fitness =  0.01405
# Generation =  396 	Best fitness =  0.01366
# Generation =  397 	Best fitness =  0.01308
# Generation =  398 	Best fitness =  0.01284
# Generation =  399 	Best fitness =  0.01284
# Generation =  400 	Best fitness =  0.01554
# Generation =  401 	Best fitness =  0.01415
# Generation =  402 	Best fitness =  0.01484
# Generation =  403 	Best fitness =  0.01505
# Generation =  404 	Best fitness =  0.01505
# Generation =  405 	Best fitness =  0.01494
# Generation =  406 	Best fitness =  0.01663
# Generation =  407 	Best fitness =  0.01513
# Generation =  408 	Best fitness =  0.01689
# Generation =  409 	Best fitness =  0.01661
# Generation =  410 	Best fitness =  0.01558
# Generation =  411 	Best fitness =  0.0136
# Generation =  412 	Best fitness =  0.0136
# Generation =  413 	Best fitness =  0.0143
# Generation =  414 	Best fitness =  0.01607
# Generation =  415 	Best fitness =  0.01607
# Generation =  416 	Best fitness =  0.01607
# Generation =  417 	Best fitness =  0.01399
# Generation =  418 	Best fitness =  0.0143
# Generation =  419 	Best fitness =  0.01546
# Generation =  420 	Best fitness =  0.01432
# Generation =  421 	Best fitness =  0.01432
# Generation =  422 	Best fitness =  0.01414
# Generation =  423 	Best fitness =  0.0141
# Generation =  424 	Best fitness =  0.0141
# Generation =  425 	Best fitness =  0.01527
# Generation =  426 	Best fitness =  0.01329
# Generation =  427 	Best fitness =  0.01329
# Generation =  428 	Best fitness =  0.01351
# Generation =  429 	Best fitness =  0.01458
# Generation =  430 	Best fitness =  0.01426
# Generation =  431 	Best fitness =  0.01458
# Generation =  432 	Best fitness =  0.01473
# Generation =  433 	Best fitness =  0.01364
# Generation =  434 	Best fitness =  0.01449
# Generation =  435 	Best fitness =  0.01475
# Generation =  436 	Best fitness =  0.01541
# Generation =  437 	Best fitness =  0.01597
# Generation =  438 	Best fitness =  0.01509
# Generation =  439 	Best fitness =  0.01355
# Generation =  440 	Best fitness =  0.01679
# Generation =  441 	Best fitness =  0.01596
# Generation =  442 	Best fitness =  0.01715
# Generation =  443 	Best fitness =  0.01715
# Generation =  444 	Best fitness =  0.01702
# Generation =  445 	Best fitness =  0.01802
# Generation =  446 	Best fitness =  0.01782
# Generation =  447 	Best fitness =  0.01681
# Generation =  448 	Best fitness =  0.01582
# Generation =  449 	Best fitness =  0.01582
# Generation =  450 	Best fitness =  0.01548
# Generation =  451 	Best fitness =  0.01441
# Generation =  452 	Best fitness =  0.01341
# Generation =  453 	Best fitness =  0.01548
# Generation =  454 	Best fitness =  0.01564
# Generation =  455 	Best fitness =  0.01564
# Generation =  456 	Best fitness =  0.01564
# Generation =  457 	Best fitness =  0.01645
# Generation =  458 	Best fitness =  0.0164
# Generation =  459 	Best fitness =  0.0164
# Generation =  460 	Best fitness =  0.01734
# Generation =  461 	Best fitness =  0.01714
# Generation =  462 	Best fitness =  0.01607
# Generation =  463 	Best fitness =  0.01592
# Generation =  464 	Best fitness =  0.0195
# Generation =  465 	Best fitness =  0.0195
# Generation =  466 	Best fitness =  0.0195
# Generation =  467 	Best fitness =  0.01924
# Generation =  468 	Best fitness =  0.01962
# Generation =  469 	Best fitness =  0.01974
# Generation =  470 	Best fitness =  0.02224
# Generation =  471 	Best fitness =  0.0213
# Generation =  472 	Best fitness =  0.0213
# Generation =  473 	Best fitness =  0.021
# Generation =  474 	Best fitness =  0.01941
# Generation =  475 	Best fitness =  0.01866
# Generation =  476 	Best fitness =  0.01747
# Generation =  477 	Best fitness =  0.01747
# Generation =  478 	Best fitness =  0.01529
# Generation =  479 	Best fitness =  0.01668
# Generation =  480 	Best fitness =  0.01633
# Generation =  481 	Best fitness =  0.01681
# Generation =  482 	Best fitness =  0.01642
# Generation =  483 	Best fitness =  0.01954
# Generation =  484 	Best fitness =  0.01958
# Generation =  485 	Best fitness =  0.01847
# Generation =  486 	Best fitness =  0.01738
# Generation =  487 	Best fitness =  0.01666
# Generation =  488 	Best fitness =  0.01735
# Generation =  489 	Best fitness =  0.01572
# Generation =  490 	Best fitness =  0.01734
# Generation =  491 	Best fitness =  0.01668
# Generation =  492 	Best fitness =  0.01605
# Generation =  493 	Best fitness =  0.01707
# Generation =  494 	Best fitness =  0.01607
# Generation =  495 	Best fitness =  0.01738
# Generation =  496 	Best fitness =  0.01464
# Generation =  497 	Best fitness =  0.01478
# Generation =  498 	Best fitness =  0.01568
# Generation =  499 	Best fitness =  0.01615
# Generation =  500 	Best fitness =  0.01603
# Generation =  501 	Best fitness =  0.01563
# Generation =  502 	Best fitness =  0.01402
# Generation =  503 	Best fitness =  0.01384
# Generation =  504 	Best fitness =  0.01377
# Generation =  505 	Best fitness =  0.01257
# Generation =  506 	Best fitness =  0.01377
# Generation =  507 	Best fitness =  0.01377
# Generation =  508 	Best fitness =  0.01413
# Generation =  509 	Best fitness =  0.01474
# Generation =  510 	Best fitness =  0.01411
# Generation =  511 	Best fitness =  0.01435
# Generation =  512 	Best fitness =  0.01459
# Generation =  513 	Best fitness =  0.01381
# Generation =  514 	Best fitness =  0.01319
# Generation =  515 	Best fitness =  0.01266
# Generation =  516 	Best fitness =  0.01179
# Generation =  517 	Best fitness =  0.0128
# Generation =  518 	Best fitness =  0.01177
# Generation =  519 	Best fitness =  0.01295
# Generation =  520 	Best fitness =  0.01356
# Generation =  521 	Best fitness =  0.01321
# Generation =  522 	Best fitness =  0.01261
# Generation =  523 	Best fitness =  0.01336
# Generation =  524 	Best fitness =  0.01412
# Generation =  525 	Best fitness =  0.0138
# Generation =  526 	Best fitness =  0.01412
# Generation =  527 	Best fitness =  0.01412
# Generation =  528 	Best fitness =  0.0144
# Generation =  529 	Best fitness =  0.01456
# Generation =  530 	Best fitness =  0.01407
# Generation =  531 	Best fitness =  0.01355
# Generation =  532 	Best fitness =  0.01403
# Generation =  533 	Best fitness =  0.01299
# Generation =  534 	Best fitness =  0.01374
# Generation =  535 	Best fitness =  0.01504
# Generation =  536 	Best fitness =  0.015
# Generation =  537 	Best fitness =  0.01434
# Generation =  538 	Best fitness =  0.01245
# Generation =  539 	Best fitness =  0.01442
# Generation =  540 	Best fitness =  0.0141
# Generation =  541 	Best fitness =  0.0141
# Generation =  542 	Best fitness =  0.01414
# Generation =  543 	Best fitness =  0.01414
# Generation =  544 	Best fitness =  0.01414
# Generation =  545 	Best fitness =  0.0145
# Generation =  546 	Best fitness =  0.015
# Generation =  547 	Best fitness =  0.01249
# Generation =  548 	Best fitness =  0.01249
# Generation =  549 	Best fitness =  0.01393
# Generation =  550 	Best fitness =  0.01336
# Generation =  551 	Best fitness =  0.01336
# Generation =  552 	Best fitness =  0.01336
# Generation =  553 	Best fitness =  0.01267
# Generation =  554 	Best fitness =  0.01267
# Generation =  555 	Best fitness =  0.01365
# Generation =  556 	Best fitness =  0.01328
# Generation =  557 	Best fitness =  0.01328
# Generation =  558 	Best fitness =  0.01221
# Generation =  559 	Best fitness =  0.01328
# Generation =  560 	Best fitness =  0.01288
# Generation =  561 	Best fitness =  0.01288
# Generation =  562 	Best fitness =  0.01445
# Generation =  563 	Best fitness =  0.01445
# Generation =  564 	Best fitness =  0.01219
# Generation =  565 	Best fitness =  0.01345
# Generation =  566 	Best fitness =  0.01284
# Generation =  567 	Best fitness =  0.01268
# Generation =  568 	Best fitness =  0.01284
# Generation =  569 	Best fitness =  0.01198
# Generation =  570 	Best fitness =  0.01198
# Generation =  571 	Best fitness =  0.01204
# Generation =  572 	Best fitness =  0.01207
# Generation =  573 	Best fitness =  0.01278
# Generation =  574 	Best fitness =  0.01246
# Generation =  575 	Best fitness =  0.01211
# Generation =  576 	Best fitness =  0.01274
# Generation =  577 	Best fitness =  0.01239
# Generation =  578 	Best fitness =  0.0125
# Generation =  579 	Best fitness =  0.01106
# Generation =  580 	Best fitness =  0.01239
# Generation =  581 	Best fitness =  0.01274
# Generation =  582 	Best fitness =  0.01274
# Generation =  583 	Best fitness =  0.01303
# Generation =  584 	Best fitness =  0.01295
# Generation =  585 	Best fitness =  0.01288
# Generation =  586 	Best fitness =  0.01295
# Generation =  587 	Best fitness =  0.01288
# Generation =  588 	Best fitness =  0.01295
# Generation =  589 	Best fitness =  0.01159
# Generation =  590 	Best fitness =  0.01325
# Generation =  591 	Best fitness =  0.01325
# Generation =  592 	Best fitness =  0.01308
# Generation =  593 	Best fitness =  0.01249
# Generation =  594 	Best fitness =  0.01249
# Generation =  595 	Best fitness =  0.01284
# Generation =  596 	Best fitness =  0.01284
# Generation =  597 	Best fitness =  0.01472
# Generation =  598 	Best fitness =  0.01279
# Generation =  599 	Best fitness =  0.01346
# Generation =  600 	Best fitness =  0.01386
# Generation =  601 	Best fitness =  0.01419
# Generation =  602 	Best fitness =  0.01168
# Generation =  603 	Best fitness =  0.01311
# Generation =  604 	Best fitness =  0.01457
# Generation =  605 	Best fitness =  0.01407
# Generation =  606 	Best fitness =  0.01317
# Generation =  607 	Best fitness =  0.01405
# Generation =  608 	Best fitness =  0.01384
# Generation =  609 	Best fitness =  0.01412
# Generation =  610 	Best fitness =  0.01426
# Generation =  611 	Best fitness =  0.01409
# Generation =  612 	Best fitness =  0.01458
# Generation =  613 	Best fitness =  0.01492
# Generation =  614 	Best fitness =  0.01495
# Generation =  615 	Best fitness =  0.01495
# Generation =  616 	Best fitness =  0.01493
# Generation =  617 	Best fitness =  0.01486
# Generation =  618 	Best fitness =  0.01418
# Generation =  619 	Best fitness =  0.01157
# Generation =  620 	Best fitness =  0.01403
# Generation =  621 	Best fitness =  0.01388
# Generation =  622 	Best fitness =  0.01157
# Generation =  623 	Best fitness =  0.01417
# Generation =  624 	Best fitness =  0.01472
# Generation =  625 	Best fitness =  0.01459
# Generation =  626 	Best fitness =  0.01287
# Generation =  627 	Best fitness =  0.01255
# Generation =  628 	Best fitness =  0.01255
# Generation =  629 	Best fitness =  0.01255
# Generation =  630 	Best fitness =  0.01349
# Generation =  631 	Best fitness =  0.01314
# Generation =  632 	Best fitness =  0.01375
# Generation =  633 	Best fitness =  0.01436
# Generation =  634 	Best fitness =  0.01235
# Generation =  635 	Best fitness =  0.01235
# Generation =  636 	Best fitness =  0.01396
# Generation =  637 	Best fitness =  0.01313
# Generation =  638 	Best fitness =  0.01511
# Generation =  639 	Best fitness =  0.01461
# Generation =  640 	Best fitness =  0.01265
# Generation =  641 	Best fitness =  0.01367
# Generation =  642 	Best fitness =  0.01444
# Generation =  643 	Best fitness =  0.01527
# Generation =  644 	Best fitness =  0.0142
# Generation =  645 	Best fitness =  0.01518
# Generation =  646 	Best fitness =  0.01446
# Generation =  647 	Best fitness =  0.01238
# Generation =  648 	Best fitness =  0.01544
# Generation =  649 	Best fitness =  0.01503
# Generation =  650 	Best fitness =  0.0153
# Generation =  651 	Best fitness =  0.01547
# Generation =  652 	Best fitness =  0.01617
# Generation =  653 	Best fitness =  0.01442
# Generation =  654 	Best fitness =  0.01434
# Generation =  655 	Best fitness =  0.01434
# Generation =  656 	Best fitness =  0.01516
# Generation =  657 	Best fitness =  0.01422
# Generation =  658 	Best fitness =  0.01447
# Generation =  659 	Best fitness =  0.01459
# Generation =  660 	Best fitness =  0.01535
# Generation =  661 	Best fitness =  0.01367
# Generation =  662 	Best fitness =  0.01347
# Generation =  663 	Best fitness =  0.01347
# Generation =  664 	Best fitness =  0.0136
# Generation =  665 	Best fitness =  0.0136
# Generation =  666 	Best fitness =  0.01421
# Generation =  667 	Best fitness =  0.01421
# Generation =  668 	Best fitness =  0.01421
# Generation =  669 	Best fitness =  0.01514
# Generation =  670 	Best fitness =  0.01494
# Generation =  671 	Best fitness =  0.01468
# Generation =  672 	Best fitness =  0.01598
# Generation =  673 	Best fitness =  0.01445
# Generation =  674 	Best fitness =  0.01385
# Generation =  675 	Best fitness =  0.01315
# Generation =  676 	Best fitness =  0.01445
# Generation =  677 	Best fitness =  0.01436
# Generation =  678 	Best fitness =  0.01267
# Generation =  679 	Best fitness =  0.01267
# Generation =  680 	Best fitness =  0.01267
# Generation =  681 	Best fitness =  0.01422
# Generation =  682 	Best fitness =  0.0124
# Generation =  683 	Best fitness =  0.0124
# Generation =  684 	Best fitness =  0.01061
# Generation =  685 	Best fitness =  0.0124
# Generation =  686 	Best fitness =  0.0124
# Generation =  687 	Best fitness =  0.01256
# Generation =  688 	Best fitness =  0.01259
# Generation =  689 	Best fitness =  0.01124
# Generation =  690 	Best fitness =  0.01135
# Generation =  691 	Best fitness =  0.01135
# Generation =  692 	Best fitness =  0.01135
# Generation =  693 	Best fitness =  0.01135
# Generation =  694 	Best fitness =  0.0133
# Generation =  695 	Best fitness =  0.01349
# Generation =  696 	Best fitness =  0.01186
# Generation =  697 	Best fitness =  0.01197
# Generation =  698 	Best fitness =  0.01314
# Generation =  699 	Best fitness =  0.01314
# Generation =  700 	Best fitness =  0.01323
# Generation =  701 	Best fitness =  0.01287
# Generation =  702 	Best fitness =  0.01261
# Generation =  703 	Best fitness =  0.01106
# Generation =  704 	Best fitness =  0.01106
# Generation =  705 	Best fitness =  0.01112
# Generation =  706 	Best fitness =  0.01068
# Generation =  707 	Best fitness =  0.01144
# Generation =  708 	Best fitness =  0.01042
# Generation =  709 	Best fitness =  0.01207
# Generation =  710 	Best fitness =  0.01192
# Generation =  711 	Best fitness =  0.01192
# Generation =  712 	Best fitness =  0.01192
# Generation =  713 	Best fitness =  0.0117
# Generation =  714 	Best fitness =  0.01172
# Generation =  715 	Best fitness =  0.01166
# Generation =  716 	Best fitness =  0.0121
# Generation =  717 	Best fitness =  0.0121
# Generation =  718 	Best fitness =  0.01383
# Generation =  719 	Best fitness =  0.0136
# Generation =  720 	Best fitness =  0.01311
# Generation =  721 	Best fitness =  0.01135
# Generation =  722 	Best fitness =  0.01094
# Generation =  723 	Best fitness =  0.01094
# Generation =  724 	Best fitness =  0.01094
# Generation =  725 	Best fitness =  0.01083
# Generation =  726 	Best fitness =  0.01079
# Generation =  727 	Best fitness =  0.01061
# Generation =  728 	Best fitness =  0.01044
# Generation =  729 	Best fitness =  0.01044
# Generation =  730 	Best fitness =  0.01044
# Generation =  731 	Best fitness =  0.01044
# Generation =  732 	Best fitness =  0.01031
# Generation =  733 	Best fitness =  0.01031
# Generation =  734 	Best fitness =  0.01031
# Generation =  735 	Best fitness =  0.01106
# Generation =  736 	Best fitness =  0.0112
# Generation =  737 	Best fitness =  0.0118
# Generation =  738 	Best fitness =  0.01067
# Generation =  739 	Best fitness =  0.01121
# Generation =  740 	Best fitness =  0.01121
# Generation =  741 	Best fitness =  0.01159
# Generation =  742 	Best fitness =  0.01172
# Generation =  743 	Best fitness =  0.01172
# Generation =  744 	Best fitness =  0.01172
# Generation =  745 	Best fitness =  0.01172
# Generation =  746 	Best fitness =  0.01213
# Generation =  747 	Best fitness =  0.01074
# Generation =  748 	Best fitness =  0.01074
# Generation =  749 	Best fitness =  0.01033
# Generation =  750 	Best fitness =  0.01087
# Generation =  751 	Best fitness =  0.01087
# Generation =  752 	Best fitness =  0.01093
# Generation =  753 	Best fitness =  0.01095
# Generation =  754 	Best fitness =  0.01095
# Generation =  755 	Best fitness =  0.01163
# Generation =  756 	Best fitness =  0.01315
# Generation =  757 	Best fitness =  0.01268
# Generation =  758 	Best fitness =  0.01325
# Generation =  759 	Best fitness =  0.01333
# Generation =  760 	Best fitness =  0.01333
# Generation =  761 	Best fitness =  0.01365
# Generation =  762 	Best fitness =  0.01056
# Generation =  763 	Best fitness =  0.01056
# Generation =  764 	Best fitness =  0.01214
# Generation =  765 	Best fitness =  0.01214
# Generation =  766 	Best fitness =  0.0131
# Generation =  767 	Best fitness =  0.01188
# Generation =  768 	Best fitness =  0.01279
# Generation =  769 	Best fitness =  0.01338
# Generation =  770 	Best fitness =  0.01248
# Generation =  771 	Best fitness =  0.01346
# Generation =  772 	Best fitness =  0.01332
# Generation =  773 	Best fitness =  0.01418
# Generation =  774 	Best fitness =  0.01418
# Generation =  775 	Best fitness =  0.01292
# Generation =  776 	Best fitness =  0.01279
# Generation =  777 	Best fitness =  0.01279
# Generation =  778 	Best fitness =  0.01424
# Generation =  779 	Best fitness =  0.01413
# Generation =  780 	Best fitness =  0.01439
# Generation =  781 	Best fitness =  0.01373
# Generation =  782 	Best fitness =  0.01577
# Generation =  783 	Best fitness =  0.01318
# Generation =  784 	Best fitness =  0.01255
# Generation =  785 	Best fitness =  0.0139
# Generation =  786 	Best fitness =  0.01309
# Generation =  787 	Best fitness =  0.01368
# Generation =  788 	Best fitness =  0.01373
# Generation =  789 	Best fitness =  0.01395
# Generation =  790 	Best fitness =  0.01371
# Generation =  791 	Best fitness =  0.01329
# Generation =  792 	Best fitness =  0.01298
# Generation =  793 	Best fitness =  0.01437
# Generation =  794 	Best fitness =  0.01308
# Generation =  795 	Best fitness =  0.01296
# Generation =  796 	Best fitness =  0.01432
# Generation =  797 	Best fitness =  0.01299
# Generation =  798 	Best fitness =  0.01368
# Generation =  799 	Best fitness =  0.01299
# Generation =  800 	Best fitness =  0.01104
# Generation =  801 	Best fitness =  0.01088
# Generation =  802 	Best fitness =  0.01066
# Generation =  803 	Best fitness =  0.01066
# Generation =  804 	Best fitness =  0.01088
# Generation =  805 	Best fitness =  0.0112
# Generation =  806 	Best fitness =  0.011
# Generation =  807 	Best fitness =  0.01148
# Generation =  808 	Best fitness =  0.01242
# Generation =  809 	Best fitness =  0.01229
# Generation =  810 	Best fitness =  0.01258
# Generation =  811 	Best fitness =  0.01131
# Generation =  812 	Best fitness =  0.01266
# Generation =  813 	Best fitness =  0.01142
# Generation =  814 	Best fitness =  0.01192
# Generation =  815 	Best fitness =  0.01148
# Generation =  816 	Best fitness =  0.01192
# Generation =  817 	Best fitness =  0.01269
# Generation =  818 	Best fitness =  0.01211
# Generation =  819 	Best fitness =  0.01161
# Generation =  820 	Best fitness =  0.01161
# Generation =  821 	Best fitness =  0.01201
# Generation =  822 	Best fitness =  0.01176
# Generation =  823 	Best fitness =  0.01225
# Generation =  824 	Best fitness =  0.01193
# Generation =  825 	Best fitness =  0.0114
# Generation =  826 	Best fitness =  0.0114
# Generation =  827 	Best fitness =  0.01234
# Generation =  828 	Best fitness =  0.01313
# Generation =  829 	Best fitness =  0.01194
# Generation =  830 	Best fitness =  0.01259
# Generation =  831 	Best fitness =  0.01365
# Generation =  832 	Best fitness =  0.01226
# Generation =  833 	Best fitness =  0.01164
# Generation =  834 	Best fitness =  0.01169
# Generation =  835 	Best fitness =  0.01169
# Generation =  836 	Best fitness =  0.01103
# Generation =  837 	Best fitness =  0.01169
# Generation =  838 	Best fitness =  0.01169
# Generation =  839 	Best fitness =  0.01188
# Generation =  840 	Best fitness =  0.01188
# Generation =  841 	Best fitness =  0.01188
# Generation =  842 	Best fitness =  0.01188
# Generation =  843 	Best fitness =  0.01169
# Generation =  844 	Best fitness =  0.01169
# Generation =  845 	Best fitness =  0.01169
# Generation =  846 	Best fitness =  0.01146
# Generation =  847 	Best fitness =  0.01205
# Generation =  848 	Best fitness =  0.01099
# Generation =  849 	Best fitness =  0.01207
# Generation =  850 	Best fitness =  0.01174
# Generation =  851 	Best fitness =  0.01192
# Generation =  852 	Best fitness =  0.01122
# Generation =  853 	Best fitness =  0.01182
# Generation =  854 	Best fitness =  0.0119
# Generation =  855 	Best fitness =  0.01221
# Generation =  856 	Best fitness =  0.01154
# Generation =  857 	Best fitness =  0.01154
# Generation =  858 	Best fitness =  0.012
# Generation =  859 	Best fitness =  0.01213
# Generation =  860 	Best fitness =  0.01213
# Generation =  861 	Best fitness =  0.01197
# Generation =  862 	Best fitness =  0.01167
# Generation =  863 	Best fitness =  0.01197
# Generation =  864 	Best fitness =  0.01364
# Generation =  865 	Best fitness =  0.01251
# Generation =  866 	Best fitness =  0.01192
# Generation =  867 	Best fitness =  0.01312
# Generation =  868 	Best fitness =  0.012
# Generation =  869 	Best fitness =  0.01363
# Generation =  870 	Best fitness =  0.01352
# Generation =  871 	Best fitness =  0.01468
# Generation =  872 	Best fitness =  0.01438
# Generation =  873 	Best fitness =  0.01451
# Generation =  874 	Best fitness =  0.01264
# Generation =  875 	Best fitness =  0.01264
# Generation =  876 	Best fitness =  0.01264
# Generation =  877 	Best fitness =  0.0108
# Generation =  878 	Best fitness =  0.0108
# Generation =  879 	Best fitness =  0.0108
# Generation =  880 	Best fitness =  0.01077
# Generation =  881 	Best fitness =  0.01332
# Generation =  882 	Best fitness =  0.01215
# Generation =  883 	Best fitness =  0.01261
# Generation =  884 	Best fitness =  0.01173
# Generation =  885 	Best fitness =  0.01268
# Generation =  886 	Best fitness =  0.01202
# Generation =  887 	Best fitness =  0.01198
# Generation =  888 	Best fitness =  0.01205
# Generation =  889 	Best fitness =  0.01136
# Generation =  890 	Best fitness =  0.01291
# Generation =  891 	Best fitness =  0.01344
# Generation =  892 	Best fitness =  0.01255
# Generation =  893 	Best fitness =  0.01372
# Generation =  894 	Best fitness =  0.01265
# Generation =  895 	Best fitness =  0.01483
# Generation =  896 	Best fitness =  0.01549
# Generation =  897 	Best fitness =  0.01445
# Generation =  898 	Best fitness =  0.01382
# Generation =  899 	Best fitness =  0.01521
# Generation =  900 	Best fitness =  0.01582
# Generation =  901 	Best fitness =  0.01672
# Generation =  902 	Best fitness =  0.01533
# Generation =  903 	Best fitness =  0.01409
# Generation =  904 	Best fitness =  0.01409
# Generation =  905 	Best fitness =  0.01504
# Generation =  906 	Best fitness =  0.0172
# Generation =  907 	Best fitness =  0.01486
# Generation =  908 	Best fitness =  0.01489
# Generation =  909 	Best fitness =  0.01489
# Generation =  910 	Best fitness =  0.01497
# Generation =  911 	Best fitness =  0.01497
# Generation =  912 	Best fitness =  0.01608
# Generation =  913 	Best fitness =  0.01526
# Generation =  914 	Best fitness =  0.01501
# Generation =  915 	Best fitness =  0.01424
# Generation =  916 	Best fitness =  0.01609
# Generation =  917 	Best fitness =  0.01609
# Generation =  918 	Best fitness =  0.01526
# Generation =  919 	Best fitness =  0.0155
# Generation =  920 	Best fitness =  0.01519
# Generation =  921 	Best fitness =  0.01437
# Generation =  922 	Best fitness =  0.01437
# Generation =  923 	Best fitness =  0.01702
# Generation =  924 	Best fitness =  0.0154
# Generation =  925 	Best fitness =  0.0154
# Generation =  926 	Best fitness =  0.01718
# Generation =  927 	Best fitness =  0.01548
# Generation =  928 	Best fitness =  0.01597
# Generation =  929 	Best fitness =  0.01627
# Generation =  930 	Best fitness =  0.01411
# Generation =  931 	Best fitness =  0.01544
# Generation =  932 	Best fitness =  0.01501
# Generation =  933 	Best fitness =  0.01501
# Generation =  934 	Best fitness =  0.01547
# Generation =  935 	Best fitness =  0.01482
# Generation =  936 	Best fitness =  0.01636
# Generation =  937 	Best fitness =  0.01697
# Generation =  938 	Best fitness =  0.0149
# Generation =  939 	Best fitness =  0.01452
# Generation =  940 	Best fitness =  0.01442
# Generation =  941 	Best fitness =  0.01569
# Generation =  942 	Best fitness =  0.01569
# Generation =  943 	Best fitness =  0.0136
# Generation =  944 	Best fitness =  0.01439
# Generation =  945 	Best fitness =  0.01445
# Generation =  946 	Best fitness =  0.01713
# Generation =  947 	Best fitness =  0.01729
# Generation =  948 	Best fitness =  0.01696
# Generation =  949 	Best fitness =  0.0183
# Generation =  950 	Best fitness =  0.01776
# Generation =  951 	Best fitness =  0.01585
# Generation =  952 	Best fitness =  0.01557
# Generation =  953 	Best fitness =  0.01557
# Generation =  954 	Best fitness =  0.01773
# Generation =  955 	Best fitness =  0.01627
# Generation =  956 	Best fitness =  0.01671
# Generation =  957 	Best fitness =  0.01671
# Generation =  958 	Best fitness =  0.01707
# Generation =  959 	Best fitness =  0.01794
# Generation =  960 	Best fitness =  0.01853
# Generation =  961 	Best fitness =  0.01853
# Generation =  962 	Best fitness =  0.01723
# Generation =  963 	Best fitness =  0.0163
# Generation =  964 	Best fitness =  0.01669
# Generation =  965 	Best fitness =  0.01669
# Generation =  966 	Best fitness =  0.01669
# Generation =  967 	Best fitness =  0.01788
# Generation =  968 	Best fitness =  0.01774
# Generation =  969 	Best fitness =  0.01751
# Generation =  970 	Best fitness =  0.01788
# Generation =  971 	Best fitness =  0.01648
# Generation =  972 	Best fitness =  0.01788
# Generation =  973 	Best fitness =  0.01697
# Generation =  974 	Best fitness =  0.01942
# Generation =  975 	Best fitness =  0.01942
# Generation =  976 	Best fitness =  0.01874
# Generation =  977 	Best fitness =  0.02091
# Generation =  978 	Best fitness =  0.01979
# Generation =  979 	Best fitness =  0.01762
# Generation =  980 	Best fitness =  0.01882
# Generation =  981 	Best fitness =  0.0165
# Generation =  982 	Best fitness =  0.01806
# Generation =  983 	Best fitness =  0.01726
# Generation =  984 	Best fitness =  0.01806
# Generation =  985 	Best fitness =  0.0173
# Generation =  986 	Best fitness =  0.01628
# Generation =  987 	Best fitness =  0.01741
# Generation =  988 	Best fitness =  0.01729
# Generation =  989 	Best fitness =  0.01729
# Generation =  990 	Best fitness =  0.01729
# Generation =  991 	Best fitness =  0.01875
# Generation =  992 	Best fitness =  0.01828
# Generation =  993 	Best fitness =  0.01835
# Generation =  994 	Best fitness =  0.01525
# Generation =  995 	Best fitness =  0.0152
# Generation =  996 	Best fitness =  0.0152
# Generation =  997 	Best fitness =  0.0152
# Generation =  998 	Best fitness =  0.01488
# Generation =  999 	Best fitness =  0.01488
# Generation =  1000 	Best fitness =  0.01446
# Generation =  1001 	Best fitness =  0.01335
# Generation =  1002 	Best fitness =  0.0143
# Generation =  1003 	Best fitness =  0.01446
# Generation =  1004 	Best fitness =  0.01446
# Generation =  1005 	Best fitness =  0.01446
# Generation =  1006 	Best fitness =  0.01335
# Generation =  1007 	Best fitness =  0.01318
# Generation =  1008 	Best fitness =  0.01407
# Generation =  1009 	Best fitness =  0.01407
# Generation =  1010 	Best fitness =  0.0149
# Generation =  1011 	Best fitness =  0.01633
# Generation =  1012 	Best fitness =  0.01445
# Generation =  1013 	Best fitness =  0.01373
# Generation =  1014 	Best fitness =  0.01305
# Generation =  1015 	Best fitness =  0.01305
# Generation =  1016 	Best fitness =  0.01305
# Generation =  1017 	Best fitness =  0.01281
# Generation =  1018 	Best fitness =  0.01485
# Generation =  1019 	Best fitness =  0.0146
# Generation =  1020 	Best fitness =  0.01378
# Generation =  1021 	Best fitness =  0.01378
# Generation =  1022 	Best fitness =  0.0141
# Generation =  1023 	Best fitness =  0.01333
# Generation =  1024 	Best fitness =  0.01349
# Generation =  1025 	Best fitness =  0.01485
# Generation =  1026 	Best fitness =  0.0146
# Generation =  1027 	Best fitness =  0.0146
# Generation =  1028 	Best fitness =  0.01534
# Generation =  1029 	Best fitness =  0.01506
# Generation =  1030 	Best fitness =  0.01481
# Generation =  1031 	Best fitness =  0.01335
# Generation =  1032 	Best fitness =  0.0129
# Generation =  1033 	Best fitness =  0.01494
# Generation =  1034 	Best fitness =  0.01494
# Generation =  1035 	Best fitness =  0.01494
# Generation =  1036 	Best fitness =  0.01567
# Generation =  1037 	Best fitness =  0.01594
# Generation =  1038 	Best fitness =  0.01594
# Generation =  1039 	Best fitness =  0.01594
# Generation =  1040 	Best fitness =  0.01469
# Generation =  1041 	Best fitness =  0.01525
# Generation =  1042 	Best fitness =  0.01514
# Generation =  1043 	Best fitness =  0.01539
# Generation =  1044 	Best fitness =  0.01625
# Generation =  1045 	Best fitness =  0.01482
# Generation =  1046 	Best fitness =  0.01248
# Generation =  1047 	Best fitness =  0.01248
# Generation =  1048 	Best fitness =  0.01248
# Generation =  1049 	Best fitness =  0.01248
# Generation =  1050 	Best fitness =  0.01248
# Generation =  1051 	Best fitness =  0.01418
# Generation =  1052 	Best fitness =  0.01383
# Generation =  1053 	Best fitness =  0.0144
# Generation =  1054 	Best fitness =  0.0144
# Generation =  1055 	Best fitness =  0.01307
# Generation =  1056 	Best fitness =  0.01249
# Generation =  1057 	Best fitness =  0.01387
# Generation =  1058 	Best fitness =  0.01137
# Generation =  1059 	Best fitness =  0.01137
# Generation =  1060 	Best fitness =  0.01424
# Generation =  1061 	Best fitness =  0.01424
# Generation =  1062 	Best fitness =  0.01519
# Generation =  1063 	Best fitness =  0.01535
# Generation =  1064 	Best fitness =  0.01571
# Generation =  1065 	Best fitness =  0.01361
# Generation =  1066 	Best fitness =  0.01597
# Generation =  1067 	Best fitness =  0.01543
# Generation =  1068 	Best fitness =  0.01503
# Generation =  1069 	Best fitness =  0.01427
# Generation =  1070 	Best fitness =  0.01221
# Generation =  1071 	Best fitness =  0.01221
# Generation =  1072 	Best fitness =  0.01221
# Generation =  1073 	Best fitness =  0.01221
# Generation =  1074 	Best fitness =  0.01468
# Generation =  1075 	Best fitness =  0.01564
# Generation =  1076 	Best fitness =  0.01564
# Generation =  1077 	Best fitness =  0.01603
# Generation =  1078 	Best fitness =  0.01539
# Generation =  1079 	Best fitness =  0.01509
# Generation =  1080 	Best fitness =  0.01548
# Generation =  1081 	Best fitness =  0.0139
# Generation =  1082 	Best fitness =  0.01555
# Generation =  1083 	Best fitness =  0.0155
# Generation =  1084 	Best fitness =  0.01475
# Generation =  1085 	Best fitness =  0.0156
# Generation =  1086 	Best fitness =  0.01488
# Generation =  1087 	Best fitness =  0.01684
# Generation =  1088 	Best fitness =  0.01684
# Generation =  1089 	Best fitness =  0.01489
# Generation =  1090 	Best fitness =  0.01643
# Generation =  1091 	Best fitness =  0.01643
# Generation =  1092 	Best fitness =  0.01621
# Generation =  1093 	Best fitness =  0.01475
# Generation =  1094 	Best fitness =  0.01475
# Generation =  1095 	Best fitness =  0.01508
# Generation =  1096 	Best fitness =  0.01508
# Generation =  1097 	Best fitness =  0.01734
# Generation =  1098 	Best fitness =  0.01489
# Generation =  1099 	Best fitness =  0.01518
# Generation =  1100 	Best fitness =  0.01756
# Generation =  1101 	Best fitness =  0.01659
# Generation =  1102 	Best fitness =  0.01659
# Generation =  1103 	Best fitness =  0.01567
# Generation =  1104 	Best fitness =  0.01655
# Generation =  1105 	Best fitness =  0.01661
# Generation =  1106 	Best fitness =  0.01635
# Generation =  1107 	Best fitness =  0.01503
# Generation =  1108 	Best fitness =  0.01646
# Generation =  1109 	Best fitness =  0.01527
# Generation =  1110 	Best fitness =  0.01178
# Generation =  1111 	Best fitness =  0.01401
# Generation =  1112 	Best fitness =  0.01401
# Generation =  1113 	Best fitness =  0.01401
# Generation =  1114 	Best fitness =  0.01401
# Generation =  1115 	Best fitness =  0.01401
# Generation =  1116 	Best fitness =  0.01736
# Generation =  1117 	Best fitness =  0.01686
# Generation =  1118 	Best fitness =  0.01413
# Generation =  1119 	Best fitness =  0.01413
# Generation =  1120 	Best fitness =  0.01482
# Generation =  1121 	Best fitness =  0.01615
# Generation =  1122 	Best fitness =  0.01438
# Generation =  1123 	Best fitness =  0.01579
# Generation =  1124 	Best fitness =  0.01639
# Generation =  1125 	Best fitness =  0.01639
# Generation =  1126 	Best fitness =  0.01547
# Generation =  1127 	Best fitness =  0.01553
# Generation =  1128 	Best fitness =  0.01474
# Generation =  1129 	Best fitness =  0.01508
# Generation =  1130 	Best fitness =  0.01282
# Generation =  1131 	Best fitness =  0.01397
# Generation =  1132 	Best fitness =  0.01352
# Generation =  1133 	Best fitness =  0.01397
# Generation =  1134 	Best fitness =  0.01397
# Generation =  1135 	Best fitness =  0.01397
# Generation =  1136 	Best fitness =  0.01397
# Generation =  1137 	Best fitness =  0.01435
# Generation =  1138 	Best fitness =  0.01435
# Generation =  1139 	Best fitness =  0.01435
# Generation =  1140 	Best fitness =  0.01354
# Generation =  1141 	Best fitness =  0.01156
# Generation =  1142 	Best fitness =  0.01156
# Generation =  1143 	Best fitness =  0.01156
# Generation =  1144 	Best fitness =  0.0121
# Generation =  1145 	Best fitness =  0.0121
# Generation =  1146 	Best fitness =  0.0121
# Generation =  1147 	Best fitness =  0.0121
# Generation =  1148 	Best fitness =  0.01256
# Generation =  1149 	Best fitness =  0.01256
# Generation =  1150 	Best fitness =  0.01246
# Generation =  1151 	Best fitness =  0.01374
# Generation =  1152 	Best fitness =  0.01374
# Generation =  1153 	Best fitness =  0.01336
# Generation =  1154 	Best fitness =  0.01304
# Generation =  1155 	Best fitness =  0.01295
# Generation =  1156 	Best fitness =  0.01441
# Generation =  1157 	Best fitness =  0.01423
# Generation =  1158 	Best fitness =  0.01339
# Generation =  1159 	Best fitness =  0.01445
# Generation =  1160 	Best fitness =  0.01245
# Generation =  1161 	Best fitness =  0.01399
# Generation =  1162 	Best fitness =  0.01287
# Generation =  1163 	Best fitness =  0.01399
# Generation =  1164 	Best fitness =  0.0139
# Generation =  1165 	Best fitness =  0.01448
# Generation =  1166 	Best fitness =  0.01361
# Generation =  1167 	Best fitness =  0.01457
# Generation =  1168 	Best fitness =  0.01289
# Generation =  1169 	Best fitness =  0.01416
# Generation =  1170 	Best fitness =  0.01401
# Generation =  1171 	Best fitness =  0.01293
# Generation =  1172 	Best fitness =  0.01293
# Generation =  1173 	Best fitness =  0.01288
# Generation =  1174 	Best fitness =  0.01133
# Generation =  1175 	Best fitness =  0.01307
# Generation =  1176 	Best fitness =  0.01128
# Generation =  1177 	Best fitness =  0.01128
# Generation =  1178 	Best fitness =  0.01289
# Generation =  1179 	Best fitness =  0.01172
# Generation =  1180 	Best fitness =  0.01172
# Generation =  1181 	Best fitness =  0.01152
# Generation =  1182 	Best fitness =  0.0129
# Generation =  1183 	Best fitness =  0.0131
# Generation =  1184 	Best fitness =  0.01167
# Generation =  1185 	Best fitness =  0.01228
# Generation =  1186 	Best fitness =  0.01214
# Generation =  1187 	Best fitness =  0.01141
# Generation =  1188 	Best fitness =  0.01087
# Generation =  1189 	Best fitness =  0.01087
# Generation =  1190 	Best fitness =  0.0115
# Generation =  1191 	Best fitness =  0.0115
# Generation =  1192 	Best fitness =  0.01112
# Generation =  1193 	Best fitness =  0.0115
# Generation =  1194 	Best fitness =  0.0115
# Generation =  1195 	Best fitness =  0.0115
# Generation =  1196 	Best fitness =  0.01097
# Generation =  1197 	Best fitness =  0.01097
# Generation =  1198 	Best fitness =  0.01097
# Generation =  1199 	Best fitness =  0.01097
#
# The population of the last generation:
# [[6 3 4 ... 0 2 4]
#  [5 3 2 ... 0 4 4]
#  [6 3 4 ... 0 3 4]
#  ...
#  [5 3 2 ... 7 4 4]
#  [6 3 4 ... 0 3 4]
#  [6 3 4 ... 0 4 4]]
# Best solution:  [[[6 3 4 5 0 4 1 3 2 4 5 3 2 1 0 2 1 3 4 2 6 0 4 1 0 2 6 3 2 2 6 0 2 1 0
#    4 6 3 2 2 6 0 2 5 3 2 1 3 2 4 1 3 2 6 3 2 1 2 2 4 1 0 2 6 3 2 1 3 2 2
#    1 3 4 1 3 2 1 3 2 2 1 3 4 5 0 4 1 0 2 2 1 3 1 6 0 4 1 0 4 4]]]

# %%
make_chart(EMR3d1, best_solution.squeeze(), variables1)

# %% [markdown]
# ### Conclusion
# * The genetic algorithm was implemented in order to find the optimal clustering formation for the data points from the EMR blood dataset.
# * As a fitness function the `Calinski-Harabasz Index` was used in order to determine how well the data is clustered.
# * The algorithm was used with the following hyperparameters:
#     `number_of_solutions=1000, number_of_parents=200, number_of_generations=1200, mutation_scale=(-1, 1), mutation_rate=2, maximum_cluster_number=9`
# * When observing the graph above, we can see that the loss (inverse of the fitness score) is decreasing from an initial value of 0.34795 to a final value of 0.01097, with a long tail in the later part of the iterations.
# * This indicates that the algorithm indeed manages to improve the `Calinski-Harabasz Index`.
# * When plotting the assigned clusters, we see that the clustering result is not optimal, there are 7 clusters instead of 3.
# * A possible explanation for the poor results is that the algorithm converges to a local minimum.
# * Possible solutions are to further tune the hyperparameters or to use different fitness functions.

# %% [markdown]
# ## Challenge 233: Reconstruct Image (Bonus)
# In this part you will attemp to generate an image which is closest to a target image given.
#
# First we will load the image from a file:

# %%
import matplotlib.image as mpimg

img=mpimg.imread('pexels-photo-57905.jpeg')

# %% [markdown]
# For simplicity (and running time), we focus on a small part of the image:

# %%
import matplotlib.pyplot as plt
imgplot = plt.imshow(img[100:200,200:300,0])

# %% [markdown]
# And we will define this part as out target image to reconstruct:

# %%
target = img[100:200,200:300,0]

# %% [markdown]
# Your mission is to generate an image starting at random noise. The goal is to get an image as close as possible to the target. Don;t worry if it's still noisy...
# FYI: GA are not the best solution for these types of problems ;)
# You can use these blog posts to give you ideas:
# https://towardsdatascience.com/genetic-algorithm-implementation-in-python-5ab67bb124a6
#
# https://heartbeat.fritz.ai/reproducing-images-using-a-genetic-algorithm-with-python-91fc701ff84

# %%
# Your code here
